# %% [markdown]
# <a href="https://colab.research.google.com/github/varunkumarprabhakar/My-Python-Codes/blob/main/AI_cooking_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import google.generativeai as genai
from google.generativeai.types import HarmCategory, HarmBlockThreshold
from google.colab import userdata

# --- Setup and Configuration ---


try:
    API_KEY = userdata.get('GOOGLE_API_KEY')
    if not API_KEY:
        raise ValueError("Please set the GOOGLE_API_KEY environment variable.")
    genai.configure(api_key=API_KEY)
except ValueError as e:
    print(f"Error: {e}")
    exit()



MODEL_NAME = 'gemini-2.5-flash'


safety_settings = {
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

def generate_response(prompt):
    """
    Sends a prompt to the Gemini API and returns the generated text response.
    """
    try:
        model = genai.GenerativeModel(
            model_name=MODEL_NAME,
            safety_settings=safety_settings
        )
        print("Generating response...")
        response = model.generate_content(prompt)

        return response.text
    except Exception as e:
        return f"An error occurred: {e}"

# --- Main application loop ---
def main():
    """
    Runs the main program loop, taking user input and generating responses.
    """
    print("Hi i am AI Cooking Assistant,LAXMI!")
    print("Type 'exit' or 'quit' to end the conversation.")
    print("-" * 50)

    while True:
        user_input = input("You: ")
        if user_input.lower() in ['exit', 'quit']:
            print("Conversation ended. Goodbye!")
            break

        if not user_input.strip():
            print("Please enter a valid prompt.")
            continue

        response = generate_response(user_input)
        print(f"LAXMI:-  {response}\n")

if __name__ == "__main__":

    main()
# Out:
# Hi i am AI Cooking Assistant,LAXMI!
# Type 'exit' or 'quit' to end the conversation.
# --------------------------------------------------
# You: suggest me some recepie without oil.
# Generating response...
# LAXMI:-  Cooking without oil is not only possible but can lead to incredibly flavorful and healthy meals! The key is to use water, vegetable broth, or even wine/vinegar for sautéing, and focus on baking, steaming, roasting (with liquids), and using natural fats from whole foods like avocados, nuts, or seeds (if those are permitted in your oil-free approach).
#
# Here are some delicious oil-free recipe suggestions:
#
# ---
#
# ### **1. Hearty Lentil & Vegetable Soup**
#
# *   **Why it's oil-free:** It's broth-based and relies on the natural creaminess of blended lentils and vegetables.
# *   **Ingredients:**
#     *   1 tbsp water or vegetable broth (for sautéing)
#     *   1 large onion, diced
#     *   2 carrots, diced
#     *   2 celery stalks, diced
# ...
